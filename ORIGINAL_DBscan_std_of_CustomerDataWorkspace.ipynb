# %% [markdown]
# <a href="https://colab.research.google.com/github/TemiOyee/Customer_Segmentation/blob/main/ORIGINAL_DBscan_std_of_CustomerDataWorkspace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
from socket import *
serv = socket(AF_INET,SOCK_STREAM)

# %%
df = pd.read_csv('CustomerDataClean.csv',sep=",", encoding='Latin-1')
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# ###### Implementing DBSCAN

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

# %%
X = StandardScaler().fit_transform(df)

X

col_list = list(df.columns)

df = pd.DataFrame(data=X, columns=col_list)

df
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# 2                  -0.454576     -0.466786             1.269843
# 3                  -0.454576     -0.368653            -1.014125
# 4                  -0.454576     -0.466786            -1.014125
# ...                      ...           ...                  ...
# 8945               -0.132643     -0.466786             1.269843
# 8946               -0.122823     -0.466786             1.269843
# 8947               -0.294893     -0.466786             0.854576
# 8948               -0.454576     -0.449352            -1.221758
# 8949               -0.454576     -0.406205             0.439310
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      -0.678661                         -0.707313
# 1                      -0.678661                         -0.916995
# 2                       2.673451                         -0.916995
# 3                      -0.399319                         -0.916995
# 4                      -0.399319                         -0.916995
# ...                          ...                               ...
# 8945                   -0.678661                          1.179833
# 8946                   -0.678661                          1.179833
# 8947                   -0.678661                          0.760469
# 8948                   -0.678661                         -0.916995
# 8949                    1.556082                         -0.916995
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  -0.675349         -0.476070      -0.511333     -0.960433
# 1                   0.573963          0.110074      -0.591796      0.688639
# 2                  -0.675349         -0.476070      -0.109020      0.826062
# 3                  -0.258913         -0.329534      -0.551565      0.826062
# 4                  -0.675349         -0.476070      -0.551565     -0.905464
# ...                      ...               ...            ...           ...
# 8945               -0.675349         -0.476070      -0.350408     -0.960433
# 8946               -0.675349         -0.476070      -0.350408     -0.960433
# 8947               -0.675349         -0.476070      -0.390639     -0.960433
# 8948                0.157527         -0.182998      -0.591796     -1.097856
# 8949                0.990398         -0.182998       0.333524     -0.905464
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0    -0.528979     -3.109675e-01         -0.525551  0.360680
# 1     0.818642      8.931021e-02          0.234227  0.360680
# 2    -0.383805     -1.016632e-01         -0.525551  0.360680
# 3    -0.598688     -4.390474e-16         -0.525551  0.360680
# 4    -0.364368     -2.657913e-01         -0.525551  0.360680
# ...        ...               ...               ...       ...
# 8945 -0.486217     -3.498541e-01          1.183951 -4.122768
# 8946 -0.503396     -4.390474e-16         -0.525551 -4.122768
# 8947 -0.570615     -3.354655e-01          0.329200 -4.122768
# 8948 -0.580536     -3.469065e-01          0.329200 -4.122768
# 8949 -0.576869     -3.329464e-01         -0.525551 -4.122768
#
# [8950 rows x 17 columns]

# %%
min_samples = df.shape[1]*2
dbscan = DBSCAN(eps=0.5, min_samples=min_samples)
clusters = dbscan.fit_predict(df)
print("clusters created: "+ str(list(set(clusters))))
# Out:
# clusters created: [0, 1, 2, -1]

# %%
# identified no clusters from the value above

# %% [markdown]
# ###### implementing DBSCAN with Elbow Method

# %%
# finding the best value of eps to use

# %%
k = min_samples if min_samples > 2 else 2
nbrs = NearestNeighbors(n_neighbors=k).fit(df)
distance, indices = nbrs.kneighbors(df)

# %%
print("min samples: "+ str(min_samples))
print("shape of distance matrix: "+ str(distance.shape)+"\n")
for enum, row in enumerate(distance[:5]):
    print("observation "+ str(enum)+": "+ str([round(x,2) for x in row]))
# Out:
# min samples: 34
# shape of distance matrix: (8950, 34)
#
# observation 0: [0.0, 0.46, 0.49, 0.49, 0.51, 0.58, 0.62, 0.62, 0.65, 0.69, 0.73, 0.74, 0.76, 0.78, 0.79, 0.79, 0.79, 0.8, 0.81, 0.81, 0.81, 0.83, 0.84, 0.84, 0.85, 0.86, 0.86, 0.86, 0.88, 0.88, 0.88, 0.89, 0.89, 0.89]
# observation 1: [0.0, 1.26, 1.34, 1.35, 1.37, 1.42, 1.44, 1.44, 1.46, 1.46, 1.48, 1.51, 1.52, 1.54, 1.56, 1.61, 1.64, 1.66, 1.69, 1.7, 1.73, 1.74, 1.74, 1.75, 1.75, 1.76, 1.76, 1.77, 1.78, 1.78, 1.78, 1.79, 1.84, 1.84]
# observation 2: [0.0, 0.4, 0.67, 0.71, 0.73, 0.76, 0.84, 0.92, 0.92, 0.95, 0.96, 0.96, 0.98, 0.98, 0.98, 1.06, 1.08, 1.09, 1.1, 1.11, 1.14, 1.14, 1.14, 1.17, 1.18, 1.19, 1.21, 1.21, 1.25, 1.25, 1.26, 1.26, 1.27, 1.28]
# observation 3: [0.0, 1.04, 1.32, 1.33, 1.42, 1.47, 1.47, 1.49, 1.49, 1.51, 1.52, 1.52, 1.54, 1.55, 1.55, 1.56, 1.57, 1.57, 1.58, 1.59, 1.59, 1.62, 1.62, 1.62, 1.63, 1.63, 1.64, 1.64, 1.64, 1.64, 1.65, 1.66, 1.66, 1.66]
# observation 4: [0.0, 0.1, 0.13, 0.16, 0.18, 0.19, 0.2, 0.21, 0.22, 0.22, 0.22, 0.23, 0.23, 0.23, 0.24, 0.24, 0.24, 0.25, 0.26, 0.26, 0.27, 0.27, 0.29, 0.3, 0.31, 0.31, 0.31, 0.32, 0.32, 0.32, 0.33, 0.33, 0.33, 0.35]

# %%
# the last cell represents the distance of the Kth farthest point
df['knn_farthest_dist'] = distance[:,-1]
df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.731989          -0.249434  -0.424900         -0.356934
# 1  0.786961           0.134325  -0.469552         -0.356934
# 2  0.447135           0.518084  -0.107668          0.108889
# 3  0.049099          -1.016953   0.232058          0.546189
# 4 -0.358775           0.518084  -0.462063         -0.347294
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.349079     -0.466786            -0.806490
# 1               -0.454576      2.605605            -1.221758
# 2               -0.454576     -0.466786             1.269843
# 3               -0.454576     -0.368653            -1.014125
# 4               -0.454576     -0.466786            -1.014125
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.678661                         -0.707313
# 1                   -0.678661                         -0.916995
# 2                    2.673451                         -0.916995
# 3                   -0.399319                         -0.916995
# 4                   -0.399319                         -0.916995
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0               -0.675349         -0.476070      -0.511333     -0.960433
# 1                0.573963          0.110074      -0.591796      0.688639
# 2               -0.675349         -0.476070      -0.109020      0.826062
# 3               -0.258913         -0.329534      -0.551565      0.826062
# 4               -0.675349         -0.476070      -0.551565     -0.905464
#
#    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT   TENURE  knn_farthest_dist
# 0 -0.528979     -3.109675e-01         -0.525551  0.36068           0.890492
# 1  0.818642      8.931021e-02          0.234227  0.36068           1.843628
# 2 -0.383805     -1.016632e-01         -0.525551  0.36068           1.276966
# 3 -0.598688     -4.390474e-16         -0.525551  0.36068           1.664485
# 4 -0.364368     -2.657913e-01         -0.525551  0.36068           0.350326

# %%
df.sort_values('knn_farthest_dist', ascending=False).reset_index()[['knn_farthest_dist']].plot()
plt.xlabel('Index')
plt.ylabel('Distance')
plt.grid(True)
plt.show()

# %%
km= DBSCAN(eps=1.2, min_samples=min_samples)
df['cluster'] = km.fit_predict(df[col_list])

df.cluster.value_counts()
# Out:
#  0    5349
# -1    3601
# Name: cluster, dtype: int64

# %% [markdown]
# PRINCIPAL COMPONENT ANALYSIS

# %%
df_frame=df[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
       'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
       'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
       'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
       'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
       'TENURE']]

# %%
pca = PCA(n_components= 2)
principal_comp= pca.fit_transform(df_frame)
principal_comp

pca_df = pd.DataFrame(data=principal_comp, columns=['PCA1','PCA2'])

pca_df

# df_cluster_pca = pd.concat([pca_df, pd.DataFrame({'cluster':y_cluster_dbs})], axis=1)
df_cluster_pca = pd.concat([pca_df, df['cluster']], axis=1)

df_cluster_pca
# Out:
#           PCA1      PCA2  cluster
# 0    -1.682220 -1.076453        0
# 1    -1.138293  2.506469       -1
# 2     0.969687 -0.383505        0
# 3    -0.873626  0.043162       -1
# 4    -1.599434 -0.688582        0
# ...        ...       ...      ...
# 8945 -0.359630 -2.016146       -1
# 8946 -0.564371 -1.639126       -1
# 8947 -0.926205 -1.810787       -1
# 8948 -2.336554 -0.657971        0
# 8949 -0.556423 -0.400461       -1
#
# [8950 rows x 3 columns]

# %%
df_cluster_pca.cluster.value_counts()
# Out:
#  0    5349
# -1    3601
# Name: cluster, dtype: int64

# %%
#Plot
plt.figure(figsize=(10,7))
plt.scatter(df_cluster_pca['PCA1'],df_cluster_pca['PCA2'],c=df_cluster_pca['cluster'])

# %% [markdown]
# #Evaluation Metrics

# %%
from sklearn.metrics import silhouette_samples, silhouette_score,calinski_harabasz_score, davies_bouldin_score, adjusted_mutual_info_score, mutual_info_score

shil_score = silhouette_score(df_frame, df['cluster'], metric='euclidean')*100
print('Silhouette_score: %.3f' % shil_score)


db_score = davies_bouldin_score(df_frame, df['cluster'])
print('Davies Bouldin_score: %.3f' % db_score)


cali_score = calinski_harabasz_score(df_frame, df['cluster'])
print('Calinski Harabasz_score: %.3f' % cali_score)
# Out:
# Silhouette_score: 18.104
# Davies Bouldin_score: 2.844
# Calinski Harabasz_score: 865.224
